# %% [markdown]
# <a href="https://colab.research.google.com/github/MalB88-eng/MAP2192/blob/main/MAP2192.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Notes
# <img src="https://www.ziprecruiter.com/svc/fotomat/public-ziprecruiter/uploads/salary_images/systems-analyst-salary.webp">

# %%
# Use for Notes

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate 100 random numbers for X and Y
X = np.random.random(100)
Y = np.random.random(100)

plt.plot(X,Y)
plt.show() # Add this line to display the plot
